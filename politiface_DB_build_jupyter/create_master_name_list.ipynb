# %%
import pandas as pd
import numpy as np
import requests

# %%
pd.options.display.max_rows = 600

# %%
data = pd.read_csv('members_congress.csv')

# %%
data
# Out:
#            CID                    CRPName Party    Office  FECCandID
# 0    N00036633             Abraham, Ralph     R      LA05  H4LA05221
# 1    N00035451                Adams, Alma     D      NC12  H4NC12100
# 2    N00003028         Aderholt, Robert B     R      AL04  H6AL04098
# 3    N00033997              Aguilar, Pete     D      CA31  H2CA31125
# 4    N00009888           Alexander, Lamar     R      TNS2  S2TN00058
# 5    N00033720           Allen, Richard W     R      GA12  H2GA12121
# 6    N00031938              Amash, Justin     R      MI03  H0MI03126
# 7    N00031177               Amodei, Mark     R      NV02  H2NV02395
# 8    N00038285           Arrington, Jodey     R      TX19  H6TX19099
# 9    N00005736               Babin, Brian     R      TX36  H6TX02079
# 10   N00037049         Bacon, Donald John     R      NE02  H6NE02125
# 11   N00042194            Balderson, Troy     R      OH12  H8OH12180
# 12   N00004367             Baldwin, Tammy     D      WIS1  S2WI00219
# ...
